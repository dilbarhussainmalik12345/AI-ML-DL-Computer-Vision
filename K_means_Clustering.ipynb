# %% [markdown]
# <a href="https://colab.research.google.com/github/dilbarhussainmalik12345/AI-ML-DL-Computer-Vision/blob/main/K_means_Clustering.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.cluster import KMeans
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('/content/salary.csv')

# %%
df
# Out:
#          Name  Age  Income($)
# 0         Ali   27      70000
# 1       Ahmed   29      90000
# 2        Khan   29      61000
# 3     Muzamil   28      60000
# 4     Tanveer   42     150000
# 5      Suhail   39     155000
# 6      Sartaj   41     160000
# 7      Sardar   38     570000
# 8       Sajad   36     162000
# 9      Munwar   35     156000
# 10      Yaqob   37     130000
# 11       Atif   26     137000
# 12    Khashif   27      45000
# 13    Bahadur   28      48000
# 14     Waheed   29      51000
# 15   Ali Khan   32      49500
# 16   Muhammad   40      53000
# 17   Sahb Ali   41      65000
# 18   Dost Ali   43      63000
# 19     Fareed   39      64000
# 20      Wahab   41      80000
# 21  Ahmed Ali   39      82000

# %%
plt.scatter(df['Age'], df['Income($)'])

# %%
km = KMeans(n_clusters = 3)
km
# Out:
# KMeans(n_clusters=3)

# %%
y_predicted = km.fit_predict(df[['Age', 'Income($)']])
y_predicted
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# array([2, 2, 2, 2, 0, 0, 0, 1, 0, 0, 0, 0, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2],
#       dtype=int32)

# %%
df['cluster'] = y_predicted
df.head()
# Out:
#       Name  Age  Income($)  cluster
# 0      Ali   27      70000        2
# 1    Ahmed   29      90000        2
# 2     Khan   29      61000        2
# 3  Muzamil   28      60000        2
# 4  Tanveer   42     150000        0

# %%
df1 = df[df.cluster == 0]
df2 = df[df.cluster == 1]
df3 = df[df.cluster == 2]

plt.scatter(df1.Age, df1['Income($)'], color = 'green')
plt.scatter(df2.Age, df2['Income($)'], color = 'red')
plt.scatter(df3.Age, df3['Income($)'], color = 'black')

#plt.scatter(km.cluster_centers_[:,0], km.cluster_centers_[:,1], color = 'purple', marker = '+', label = 'centroid')

plt.xlabel('Age')
plt.ylabel('Income($)')
plt.legend()
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
scaler = MinMaxScaler()
scaler.fit(df[['Income($)']])
df[['Income($)']] = scaler.transform(df[['Income($)']])
df
# Out:
#          Name  Age  Income($)  cluster
# 0         Ali   27   0.047619        2
# 1       Ahmed   29   0.085714        2
# 2        Khan   29   0.030476        2
# 3     Muzamil   28   0.028571        2
# 4     Tanveer   42   0.200000        0
# 5      Suhail   39   0.209524        0
# 6      Sartaj   41   0.219048        0
# 7      Sardar   38   1.000000        1
# 8       Sajad   36   0.222857        0
# 9      Munwar   35   0.211429        0
# 10      Yaqob   37   0.161905        0
# 11       Atif   26   0.175238        0
# 12    Khashif   27   0.000000        2
# 13    Bahadur   28   0.005714        2
# 14     Waheed   29   0.011429        2
# 15   Ali Khan   32   0.008571        2
# 16   Muhammad   40   0.015238        2
# 17   Sahb Ali   41   0.038095        2
# 18   Dost Ali   43   0.034286        2
# 19     Fareed   39   0.036190        2
# 20      Wahab   41   0.066667        2
# 21  Ahmed Ali   39   0.070476        2

# %%
scaler.fit([df.Age])
[df.Age] = scaler.transform([df.Age])
df
# Out:
#          Name  Age  Income($)  cluster
# 0         Ali  0.0   0.047619        2
# 1       Ahmed  0.0   0.085714        2
# 2        Khan  0.0   0.030476        2
# 3     Muzamil  0.0   0.028571        2
# 4     Tanveer  0.0   0.200000        0
# 5      Suhail  0.0   0.209524        0
# 6      Sartaj  0.0   0.219048        0
# 7      Sardar  0.0   1.000000        1
# 8       Sajad  0.0   0.222857        0
# 9      Munwar  0.0   0.211429        0
# 10      Yaqob  0.0   0.161905        0
# 11       Atif  0.0   0.175238        0
# 12    Khashif  0.0   0.000000        2
# 13    Bahadur  0.0   0.005714        2
# 14     Waheed  0.0   0.011429        2
# 15   Ali Khan  0.0   0.008571        2
# 16   Muhammad  0.0   0.015238        2
# 17   Sahb Ali  0.0   0.038095        2
# 18   Dost Ali  0.0   0.034286        2
# 19     Fareed  0.0   0.036190        2
# 20      Wahab  0.0   0.066667        2
# 21  Ahmed Ali  0.0   0.070476        2

# %%
km = KMeans(n_clusters = 3)
y_predicted = km.fit_predict(df[['Age', 'Income($)']])
y_predicted
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# array([2, 2, 2, 2, 0, 0, 0, 1, 0, 0, 0, 0, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2],
#       dtype=int32)

# %%
df['cluster'] = y_predicted
df.drop('cluster', axis = 'columns', inplace = True)
df
# Out:
#          Name  Age  Income($)
# 0         Ali  0.0   0.047619
# 1       Ahmed  0.0   0.085714
# 2        Khan  0.0   0.030476
# 3     Muzamil  0.0   0.028571
# 4     Tanveer  0.0   0.200000
# 5      Suhail  0.0   0.209524
# 6      Sartaj  0.0   0.219048
# 7      Sardar  0.0   1.000000
# 8       Sajad  0.0   0.222857
# 9      Munwar  0.0   0.211429
# 10      Yaqob  0.0   0.161905
# 11       Atif  0.0   0.175238
# 12    Khashif  0.0   0.000000
# 13    Bahadur  0.0   0.005714
# 14     Waheed  0.0   0.011429
# 15   Ali Khan  0.0   0.008571
# 16   Muhammad  0.0   0.015238
# 17   Sahb Ali  0.0   0.038095
# 18   Dost Ali  0.0   0.034286
# 19     Fareed  0.0   0.036190
# 20      Wahab  0.0   0.066667
# 21  Ahmed Ali  0.0   0.070476

# %%
k_rng = range(1, 10)
sse = []
for k in k_rng:
  km = KMeans(n_clusters = k)
  km.fit(df[['Age', 'Income($)']])
  sse.append(km.inertia_)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# ...

# %%
sse
# Out:
# [0.9315785198928054,
#  0.1402131087355577,
#  0.011955490767735666,
#  0.005707845804988663,
#  0.0029421315192743767,
#  0.0009699168556311412,
#  0.0007357823129251707,
#  0.0005398639455782316,
#  0.0003743008314436889]

# %%
plt.xlabel('K')
plt.ylabel('Sum of Squared Error')
plt.plot(k_rng, sse)
